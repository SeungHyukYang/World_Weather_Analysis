# %%
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests
import random

# %%
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
coords = list(zip(lats,lngs))

# %%
cities = []
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    if (city,country) not in cities:
        cities.append((city,country))
len(cities)
# Out:
# 744

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | bluff
# Processing Record 2 of the Set 1 | upernavik
# Processing Record 3 of the Set 1 | rikitea
# Processing Record 4 of the Set 1 | palora
# Processing Record 5 of the Set 1 | yetkul
# Processing Record 6 of the Set 1 | port alfred
# Processing Record 7 of the Set 1 | tuktoyaktuk
# Processing Record 8 of the Set 1 | ushuaia
# Processing Record 9 of the Set 1 | punta arenas
# Processing Record 10 of the Set 1 | ponta do sol
# Processing Record 11 of the Set 1 | huntsville
# Processing Record 12 of the Set 1 | falmouth
# Processing Record 13 of the Set 1 | sivaki
# Processing Record 14 of the Set 1 | severo-kurilsk
# Processing Record 15 of the Set 1 | ambilobe
# Processing Record 16 of the Set 1 | ilulissat
# Processing Record 17 of the Set 1 | port elizabeth
# Processing Record 18 of the Set 1 | eloy
# Processing Record 19 of the Set 1 | illoqqortoormiut
# Processing Record 20 of the Set 1 | nsanje
# Processing Record 21 of the Set 1 | busselton
# Processing Record 22 of the Set 1 | carnarvon
# Processing Record 23 of the Set 1 | mortka
# Processing Record 24 of the Set 1 | saint-philippe
# Processing Record 25 of the Set 1 | sebeta
# Processing Record 26 of the Set 1 | vila velha
# Processing Record 27 of the Set 1 | moba
# Processing Record 28 of the Set 1 | tumannyy
# Processing Record 29 of the Set 1 | mahebourg
# Processing Record 30 of the Set 1 | saldanha
# Processing Record 31 of the Set 1 | hilo
# Processing Record 32 of the Set 1 | roald
# Processing Record 33 of the Set 1 | amderma
# Processing Record 34 of the Set 1 | panjakent
# Processing Record 35 of the Set 1 | ribeira grande
# Processing Record 36 of the Set 1 | sassandra
# Processing Record 37 of the Set 1 | parit buntar
# Processing Record 38 of the Set 1 | kapaa
# Processing Record 39 of the Set 1 | hervey bay
# Processing Record 40 of the Set 1 | avarua
# Processing Record 41 of the Set 1 | yellowknife
# Processing Record 42 of the Set 1 | beloha
# Processing Record 43 of the Set 1 | luderitz
# Processing Record 44 of the Set 1 | batemans bay
# Processing Record 45 of the Set 1 | jamestown
# Processing Record 46 of the Set 1 | east london
# Processing Record 47 of the Set 1 | taolanaro
# Processing Record 48 of the Set 1 | kharan
# Processing Record 49 of the Set 1 | poum
# Processing Record 50 of the Set 1 | tiksi
# Processing Record 1 of the Set 2 | saint george
# Processing Record 2 of the Set 2 | vaini
# Processing Record 3 of the Set 2 | marawi
# Processing Record 4 of the Set 2 | victoria
# Processing Record 5 of the Set 2 | ponta do sol
# Processing Record 6 of the Set 2 | kyra
# Processing Record 7 of the Set 2 | enshi
# Processing Record 8 of the Set 2 | bay roberts
# Processing Record 9 of the Set 2 | chuy
# Processing Record 10 of the Set 2 | flinders
# Processing Record 11 of the Set 2 | taltal
# Processing Record 12 of the Set 2 | guantanamo
# Processing Record 13 of the Set 2 | airai
# Processing Record 14 of the Set 2 | fernie
# Processing Record 15 of the Set 2 | iqaluit
# Processing Record 16 of the Set 2 | bahia blanca
# Processing Record 17 of the Set 2 | hasaki
# Processing Record 18 of the Set 2 | janauba
# Processing Record 19 of the Set 2 | port lincoln
# Processing Record 20 of the Set 2 | bethel
# Processing Record 21 of the Set 2 | geraldton
# Processing Record 22 of the Set 2 | carutapera
# Processing Record 23 of the Set 2 | butaritari
# Processing Record 24 of the Set 2 | ulaanbaatar
# Processing Record 25 of the Set 2 | bredasdorp
# Processing Record 26 of the Set 2 | karak
# Processing Record 27 of the Set 2 | santiago de compostela
# Processing Record 28 of the Set 2 | faanui
# Processing Record 29 of the Set 2 | nikolskoye
# Processing Record 30 of the Set 2 | xuddur
# Processing Record 31 of the Set 2 | provideniya
# Processing Record 32 of the Set 2 | nome
# Processing Record 33 of the Set 2 | crab hill
# City not found. Skipping...
# Processing Record 34 of the Set 2 | san cristobal
# Processing Record 35 of the Set 2 | port-gentil
# Processing Record 36 of the Set 2 | new norfolk
# Processing Record 37 of the Set 2 | dalby
# Processing Record 38 of the Set 2 | sitka
# Processing Record 39 of the Set 2 | todos santos
# Processing Record 40 of the Set 2 | kavieng
# Processing Record 41 of the Set 2 | sentyabrskiy
# Processing Record 42 of the Set 2 | kruisfontein
# Processing Record 43 of the Set 2 | saint-louis
# Processing Record 44 of the Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of the Set 2 | westport
# Processing Record 46 of the Set 2 | hithadhoo
# Processing Record 47 of the Set 2 | mildura
# Processing Record 48 of the Set 2 | walvis bay
# Processing Record 49 of the Set 2 | conceicao da barra
# Processing Record 50 of the Set 2 | chistogorskiy
# Processing Record 1 of the Set 3 | udachnyy
# Processing Record 2 of the Set 3 | sangar
# Processing Record 3 of the Set 3 | neuquen
# Processing Record 4 of the Set 3 | barcelos
# Processing Record 5 of the Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 6 of the Set 3 | nalut
# Processing Record 7 of the Set 3 | dasoguz
# Processing Record 8 of the Set 3 | huadian
# Processing Record 9 of the Set 3 | shelopugino
# Processing Record 10 of the Set 3 | praia da vitoria
# Processing Record 11 of the Set 3 | touros
# Processing Record 12 of the Set 3 | mnogovershinnyy
# Processing Record 13 of the Set 3 | mataura
# Processing Record 14 of the Set 3 | kodiak
# Processing Record 15 of the Set 3 | port blair
# Processing Record 16 of the Set 3 | saint-joseph
# Processing Record 17 of the Set 3 | cabo san lucas
# Processing Record 18 of the Set 3 | arraial do cabo
# Processing Record 19 of the Set 3 | tutoia
# Processing Record 20 of the Set 3 | saskylakh
# Processing Record 21 of the Set 3 | puerto ayora
# Processing Record 22 of the Set 3 | inirida
# Processing Record 23 of the Set 3 | ahuimanu
# Processing Record 24 of the Set 3 | hobart
# Processing Record 25 of the Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of the Set 3 | faya
# Processing Record 27 of the Set 3 | clyde river
# Processing Record 28 of the Set 3 | tasiilaq
# Processing Record 29 of the Set 3 | atuona
# Processing Record 30 of the Set 3 | dolbeau
# Processing Record 31 of the Set 3 | hobyo
# Processing Record 32 of the Set 3 | albany
# Processing Record 33 of the Set 3 | upington
# Processing Record 34 of the Set 3 | karratha
# Processing Record 35 of the Set 3 | morant bay
# Processing Record 36 of the Set 3 | kadykchan
# Processing Record 37 of the Set 3 | mar del plata
# Processing Record 38 of the Set 3 | mataram
# Processing Record 39 of the Set 3 | halalo
# City not found. Skipping...
# Processing Record 40 of the Set 3 | puerto escondido
# Processing Record 41 of the Set 3 | lloydminster
# Processing Record 42 of the Set 3 | khani
# Processing Record 43 of the Set 3 | muros
# Processing Record 44 of the Set 3 | katsuura
# Processing Record 45 of the Set 3 | bichura
# Processing Record 46 of the Set 3 | cape town
# Processing Record 47 of the Set 3 | belushya guba
# Processing Record 48 of the Set 3 | laem sing
# Processing Record 49 of the Set 3 | ngukurr
# Processing Record 50 of the Set 3 | neiba
# Processing Record 1 of the Set 4 | goderich
# Processing Record 2 of the Set 4 | vestmannaeyjar
# Processing Record 3 of the Set 4 | santarem
# Processing Record 4 of the Set 4 | salinopolis
# Processing Record 5 of the Set 4 | codrington
# Processing Record 6 of the Set 4 | khatanga
# Processing Record 7 of the Set 4 | kokopo
# Processing Record 8 of the Set 4 | innisfail
# Processing Record 9 of the Set 4 | hermanus
# Processing Record 10 of the Set 4 | halifax
# Processing Record 11 of the Set 4 | cherskiy
# Processing Record 12 of the Set 4 | namsos
# Processing Record 13 of the Set 4 | yarmouth
# Processing Record 14 of the Set 4 | tsihombe
# Processing Record 15 of the Set 4 | high rock
# Processing Record 16 of the Set 4 | broken hill
# Processing Record 17 of the Set 4 | kahului
# Processing Record 18 of the Set 4 | chokurdakh
# Processing Record 19 of the Set 4 | okhotsk
# Processing Record 20 of the Set 4 | panzhihua
# Processing Record 21 of the Set 4 | souillac
# Processing Record 22 of the Set 4 | burica
# City not found. Skipping...
# Processing Record 23 of the Set 4 | pacific grove
# Processing Record 24 of the Set 4 | krasnoselkup
# Processing Record 25 of the Set 4 | sinkat
# Processing Record 26 of the Set 4 | stornoway
# Processing Record 27 of the Set 4 | fortuna
# Processing Record 28 of the Set 4 | saint anthony
# Processing Record 29 of the Set 4 | kailua
# Processing Record 30 of the Set 4 | berezhany
# Processing Record 31 of the Set 4 | nelson bay
# Processing Record 32 of the Set 4 | castro
# Processing Record 33 of the Set 4 | otta
# Processing Record 34 of the Set 4 | paradwip
# Processing Record 35 of the Set 4 | bathsheba
# City not found. Skipping...
# Processing Record 36 of the Set 4 | sao filipe
# Processing Record 37 of the Set 4 | dikson
# Processing Record 38 of the Set 4 | barrow
# Processing Record 39 of the Set 4 | taoudenni
# Processing Record 40 of the Set 4 | port augusta
# Processing Record 41 of the Set 4 | qaanaaq
# Processing Record 42 of the Set 4 | oktyabrskiy
# Processing Record 43 of the Set 4 | steinheim
# Processing Record 44 of the Set 4 | yeniseysk
# Processing Record 45 of the Set 4 | rio grande
# Processing Record 46 of the Set 4 | fort nelson
# Processing Record 47 of the Set 4 | esperance
# Processing Record 48 of the Set 4 | fountain
# Processing Record 49 of the Set 4 | comodoro rivadavia
# Processing Record 50 of the Set 4 | erzincan
# Processing Record 1 of the Set 5 | norman wells
# Processing Record 2 of the Set 5 | aklavik
# Processing Record 3 of the Set 5 | thompson
# Processing Record 4 of the Set 5 | xining
# Processing Record 5 of the Set 5 | matara
# Processing Record 6 of the Set 5 | agadez
# Processing Record 7 of the Set 5 | san patricio
# Processing Record 8 of the Set 5 | hofn
# Processing Record 9 of the Set 5 | sao felix do xingu
# Processing Record 10 of the Set 5 | mys shmidta
# Processing Record 11 of the Set 5 | kirakira
# Processing Record 12 of the Set 5 | nouadhibou
# Processing Record 13 of the Set 5 | el balyana
# City not found. Skipping...
# Processing Record 14 of the Set 5 | sao raimundo nonato
# Processing Record 15 of the Set 5 | haines junction
# Processing Record 16 of the Set 5 | richards bay
# Processing Record 17 of the Set 5 | gornopravdinsk
# Processing Record 18 of the Set 5 | yaounde
# Processing Record 19 of the Set 5 | bambous virieux
# Processing Record 20 of the Set 5 | ibra
# Processing Record 21 of the Set 5 | talnakh
# Processing Record 22 of the Set 5 | utiroa
# Processing Record 23 of the Set 5 | ryotsu
# Processing Record 24 of the Set 5 | lavrentiya
# Processing Record 25 of the Set 5 | bengkulu
# Processing Record 26 of the Set 5 | berlevag
# Processing Record 27 of the Set 5 | sioux lookout
# Processing Record 28 of the Set 5 | phon
# Processing Record 29 of the Set 5 | husavik
# Processing Record 30 of the Set 5 | kaitangata
# Processing Record 31 of the Set 5 | torbay
# Processing Record 32 of the Set 5 | nindiri
# Processing Record 33 of the Set 5 | noumea
# Processing Record 34 of the Set 5 | along
# Processing Record 35 of the Set 5 | miranda do corvo
# Processing Record 36 of the Set 5 | marquette
# Processing Record 37 of the Set 5 | harper
# Processing Record 38 of the Set 5 | baykit
# Processing Record 39 of the Set 5 | paripiranga
# Processing Record 40 of the Set 5 | valdivia
# Processing Record 41 of the Set 5 | nha trang
# Processing Record 42 of the Set 5 | safaga
# City not found. Skipping...
# Processing Record 43 of the Set 5 | evensk
# Processing Record 44 of the Set 5 | barentu
# Processing Record 45 of the Set 5 | namatanai
# Processing Record 46 of the Set 5 | yarovoye
# Processing Record 47 of the Set 5 | tura
# Processing Record 48 of the Set 5 | bayir
# Processing Record 49 of the Set 5 | ngunguru
# Processing Record 50 of the Set 5 | basoko
# Processing Record 1 of the Set 6 | warqla
# City not found. Skipping...
# Processing Record 2 of the Set 6 | dunedin
# Processing Record 3 of the Set 6 | ilam
# Processing Record 4 of the Set 6 | portland
# Processing Record 5 of the Set 6 | zhezkazgan
# City not found. Skipping...
# Processing Record 6 of the Set 6 | olafsvik
# Processing Record 7 of the Set 6 | chongwe
# Processing Record 8 of the Set 6 | inhambane
# Processing Record 9 of the Set 6 | andenes
# Processing Record 10 of the Set 6 | karaul
# Processing Record 11 of the Set 6 | progreso
# Processing Record 12 of the Set 6 | naduvattam
# Processing Record 13 of the Set 6 | mehran
# Processing Record 14 of the Set 6 | nisia floresta
# Processing Record 15 of the Set 6 | zolotinka
# Processing Record 16 of the Set 6 | kalmunai
# Processing Record 17 of the Set 6 | gayny
# Processing Record 18 of the Set 6 | sinegorye
# Processing Record 19 of the Set 6 | leningradskiy
# Processing Record 20 of the Set 6 | korla
# Processing Record 21 of the Set 6 | rawson
# Processing Record 22 of the Set 6 | muisne
# Processing Record 23 of the Set 6 | ust-nera
# Processing Record 24 of the Set 6 | laramie
# Processing Record 25 of the Set 6 | teacapan
# Processing Record 26 of the Set 6 | sikonge
# Processing Record 27 of the Set 6 | havre-saint-pierre
# Processing Record 28 of the Set 6 | puerto narino
# Processing Record 29 of the Set 6 | cessnock
# Processing Record 30 of the Set 6 | henties bay
# Processing Record 31 of the Set 6 | san quintin
# Processing Record 32 of the Set 6 | yeppoon
# Processing Record 33 of the Set 6 | itoman
# Processing Record 34 of the Set 6 | labuhan
# Processing Record 35 of the Set 6 | elizabeth city
# Processing Record 36 of the Set 6 | lompoc
# Processing Record 37 of the Set 6 | slave lake
# Processing Record 38 of the Set 6 | paris
# Processing Record 39 of the Set 6 | jiangyou
# Processing Record 40 of the Set 6 | makakilo city
# Processing Record 41 of the Set 6 | hope
# Processing Record 42 of the Set 6 | leeton
# Processing Record 43 of the Set 6 | georgetown
# Processing Record 44 of the Set 6 | abu samrah
# Processing Record 45 of the Set 6 | sao joao da barra
# Processing Record 46 of the Set 6 | aflu
# City not found. Skipping...
# Processing Record 47 of the Set 6 | zhigansk
# Processing Record 48 of the Set 6 | galesburg
# Processing Record 49 of the Set 6 | la plata
# Processing Record 50 of the Set 6 | huayang
# Processing Record 1 of the Set 7 | port shepstone
# Processing Record 2 of the Set 7 | georgiyevskoye
# Processing Record 3 of the Set 7 | hambantota
# Processing Record 4 of the Set 7 | turan
# Processing Record 5 of the Set 7 | gat
# Processing Record 6 of the Set 7 | margate
# Processing Record 7 of the Set 7 | sabha
# Processing Record 8 of the Set 7 | nhulunbuy
# Processing Record 9 of the Set 7 | kongolo
# Processing Record 10 of the Set 7 | madang
# Processing Record 11 of the Set 7 | caravelas
# Processing Record 12 of the Set 7 | kufstein
# Processing Record 13 of the Set 7 | inuvik
# Processing Record 14 of the Set 7 | maghama
# Processing Record 15 of the Set 7 | valdemarpils
# Processing Record 16 of the Set 7 | havoysund
# Processing Record 17 of the Set 7 | abu kamal
# Processing Record 18 of the Set 7 | grevenbroich
# Processing Record 19 of the Set 7 | dzaoudzi
# Processing Record 20 of the Set 7 | hihifo
# Processing Record 21 of the Set 7 | omboue
# Processing Record 22 of the Set 7 | bur gabo
# Processing Record 23 of the Set 7 | te anau
# Processing Record 24 of the Set 7 | beringovskiy
# Processing Record 25 of the Set 7 | pevek
# Processing Record 26 of the Set 7 | los llanos de aridane
# Processing Record 27 of the Set 7 | naron
# Processing Record 28 of the Set 7 | te karaka
# Processing Record 29 of the Set 7 | nguiu
# Processing Record 30 of the Set 7 | columbus
# Processing Record 31 of the Set 7 | waw
# Processing Record 32 of the Set 7 | priponesti
# Processing Record 33 of the Set 7 | guerrero negro
# Processing Record 34 of the Set 7 | fairbanks
# Processing Record 35 of the Set 7 | paharpur
# Processing Record 36 of the Set 7 | hermiston
# Processing Record 37 of the Set 7 | tabora
# Processing Record 38 of the Set 7 | tungor
# Processing Record 39 of the Set 7 | asau
# Processing Record 40 of the Set 7 | lebu
# Processing Record 41 of the Set 7 | dondo
# Processing Record 42 of the Set 7 | warrington
# Processing Record 43 of the Set 7 | sorong
# Processing Record 44 of the Set 7 | mrirt
# City not found. Skipping...
# Processing Record 45 of the Set 7 | chinsali
# Processing Record 46 of the Set 7 | teahupoo
# Processing Record 47 of the Set 7 | lashio
# Processing Record 48 of the Set 7 | urumqi
# Processing Record 49 of the Set 7 | skjervoy
# Processing Record 50 of the Set 7 | waipawa
# Processing Record 1 of the Set 8 | broome
# Processing Record 2 of the Set 8 | ostuni
# Processing Record 3 of the Set 8 | lagoa
# Processing Record 4 of the Set 8 | mechernich
# Processing Record 5 of the Set 8 | villarrica
# Processing Record 6 of the Set 8 | masvingo
# Processing Record 7 of the Set 8 | aswan
# City not found. Skipping...
# Processing Record 8 of the Set 8 | vilyuysk
# Processing Record 9 of the Set 8 | chateauroux
# Processing Record 10 of the Set 8 | trincomalee
# Processing Record 11 of the Set 8 | marmarion
# Processing Record 12 of the Set 8 | malanje
# Processing Record 13 of the Set 8 | gornozavodsk
# Processing Record 14 of the Set 8 | manokwari
# Processing Record 15 of the Set 8 | bilibino
# Processing Record 16 of the Set 8 | pozo colorado
# Processing Record 17 of the Set 8 | oranjemund
# Processing Record 18 of the Set 8 | uruguaiana
# Processing Record 19 of the Set 8 | sandpoint
# Processing Record 20 of the Set 8 | clinton
# Processing Record 21 of the Set 8 | tuatapere
# Processing Record 22 of the Set 8 | acapulco
# Processing Record 23 of the Set 8 | grand-lahou
# Processing Record 24 of the Set 8 | kokkola
# Processing Record 25 of the Set 8 | angoche
# Processing Record 26 of the Set 8 | yangjiang
# Processing Record 27 of the Set 8 | buncrana
# Processing Record 28 of the Set 8 | umzimvubu
# Processing Record 29 of the Set 8 | port said
# City not found. Skipping...
# Processing Record 30 of the Set 8 | tezu
# Processing Record 31 of the Set 8 | katherine
# Processing Record 32 of the Set 8 | garm
# Processing Record 33 of the Set 8 | meulaboh
# Processing Record 34 of the Set 8 | hamilton
# Processing Record 35 of the Set 8 | takoradi
# Processing Record 36 of the Set 8 | saint-francois
# Processing Record 37 of the Set 8 | nizhneyansk
# Processing Record 38 of the Set 8 | leninogorsk
# Processing Record 39 of the Set 8 | aksarka
# Processing Record 40 of the Set 8 | katobu
# Processing Record 41 of the Set 8 | bengkalis
# Processing Record 42 of the Set 8 | vardo
# Processing Record 43 of the Set 8 | borzna
# Processing Record 44 of the Set 8 | burnie
# Processing Record 45 of the Set 8 | yarkovo
# Processing Record 46 of the Set 8 | knysna
# Processing Record 47 of the Set 8 | berbera
# Processing Record 48 of the Set 8 | mountain home
# Processing Record 49 of the Set 8 | marsaxlokk
# Processing Record 50 of the Set 8 | sambava
# Processing Record 1 of the Set 9 | shu
# Processing Record 2 of the Set 9 | huazolotitlan
# Processing Record 3 of the Set 9 | monrovia
# Processing Record 4 of the Set 9 | nanortalik
# Processing Record 5 of the Set 9 | kloulklubed
# Processing Record 6 of the Set 9 | sergeyevka
# Processing Record 7 of the Set 9 | tytuvenai
# Processing Record 8 of the Set 9 | lipin bor
# Processing Record 9 of the Set 9 | cayenne
# Processing Record 10 of the Set 9 | mayumba
# Processing Record 11 of the Set 9 | opuwo
# Processing Record 12 of the Set 9 | tocopilla
# Processing Record 13 of the Set 9 | grand forks
# Processing Record 14 of the Set 9 | tura
# Processing Record 15 of the Set 9 | chernyshevskiy
# Processing Record 16 of the Set 9 | piacabucu
# Processing Record 17 of the Set 9 | adrar
# City not found. Skipping...
# Processing Record 18 of the Set 9 | safwah
# City not found. Skipping...
# Processing Record 19 of the Set 9 | avera
# Processing Record 20 of the Set 9 | ust-tsilma
# Processing Record 21 of the Set 9 | bolotnoye
# Processing Record 22 of the Set 9 | vysokaya gora
# Processing Record 23 of the Set 9 | la union
# Processing Record 24 of the Set 9 | portobelo
# Processing Record 25 of the Set 9 | hunza
# Processing Record 26 of the Set 9 | olot
# Processing Record 27 of the Set 9 | belmonte
# Processing Record 28 of the Set 9 | ambon
# Processing Record 29 of the Set 9 | kortkeros
# Processing Record 30 of the Set 9 | chapais
# Processing Record 31 of the Set 9 | axim
# Processing Record 32 of the Set 9 | kefalos
# Processing Record 33 of the Set 9 | gibara
# Processing Record 34 of the Set 9 | cidreira
# Processing Record 35 of the Set 9 | borba
# Processing Record 36 of the Set 9 | alta floresta
# Processing Record 37 of the Set 9 | commerce
# Processing Record 38 of the Set 9 | huarmey
# Processing Record 39 of the Set 9 | almenara
# Processing Record 40 of the Set 9 | jiddah
# City not found. Skipping...
# Processing Record 41 of the Set 9 | vrede
# Processing Record 42 of the Set 9 | kuah
# Processing Record 43 of the Set 9 | darnah
# Processing Record 44 of the Set 9 | lixourion
# Processing Record 45 of the Set 9 | abu zabad
# Processing Record 46 of the Set 9 | mendahara
# Processing Record 47 of the Set 9 | saleaula
# City not found. Skipping...
# Processing Record 48 of the Set 9 | isangel
# Processing Record 49 of the Set 9 | grand river south east
# Processing Record 50 of the Set 9 | nichinan
# Processing Record 1 of the Set 10 | makat
# Processing Record 2 of the Set 10 | ewo
# Processing Record 3 of the Set 10 | lishui
# Processing Record 4 of the Set 10 | edosaki
# Processing Record 5 of the Set 10 | freeport
# Processing Record 6 of the Set 10 | acari
# Processing Record 7 of the Set 10 | manyana
# Processing Record 8 of the Set 10 | ahipara
# Processing Record 9 of the Set 10 | kuching
# Processing Record 10 of the Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of the Set 10 | belaya gora
# Processing Record 12 of the Set 10 | tevaitoa
# Processing Record 13 of the Set 10 | guaruja
# Processing Record 14 of the Set 10 | hakkari
# Processing Record 15 of the Set 10 | banda aceh
# Processing Record 16 of the Set 10 | awbari
# Processing Record 17 of the Set 10 | cuamba
# Processing Record 18 of the Set 10 | salalah
# Processing Record 19 of the Set 10 | barmer
# Processing Record 20 of the Set 10 | tatarsk
# Processing Record 21 of the Set 10 | pedasi
# Processing Record 22 of the Set 10 | attawapiskat
# Processing Record 23 of the Set 10 | vila franca do campo
# Processing Record 24 of the Set 10 | novo aripuana
# Processing Record 25 of the Set 10 | sovetskaya gavan
# Processing Record 26 of the Set 10 | rocha
# Processing Record 27 of the Set 10 | coihaique
# Processing Record 28 of the Set 10 | luanda
# Processing Record 29 of the Set 10 | dingle
# Processing Record 30 of the Set 10 | biak
# Processing Record 31 of the Set 10 | mount isa
# Processing Record 32 of the Set 10 | moron
# Processing Record 33 of the Set 10 | mogadishu
# Processing Record 34 of the Set 10 | praia
# Processing Record 35 of the Set 10 | longyearbyen
# Processing Record 36 of the Set 10 | moree
# Processing Record 37 of the Set 10 | tallahassee
# Processing Record 38 of the Set 10 | tautira
# Processing Record 39 of the Set 10 | bonavista
# Processing Record 40 of the Set 10 | onega
# Processing Record 41 of the Set 10 | butembo
# Processing Record 42 of the Set 10 | ippy
# Processing Record 43 of the Set 10 | chestermere
# Processing Record 44 of the Set 10 | samarkand
# Processing Record 45 of the Set 10 | tyrma
# Processing Record 46 of the Set 10 | khasan
# Processing Record 47 of the Set 10 | daru
# Processing Record 48 of the Set 10 | palabuhanratu
# Processing Record 49 of the Set 10 | shellbrook
# Processing Record 50 of the Set 10 | mount gambier
# Processing Record 1 of the Set 11 | baruun-urt
# Processing Record 2 of the Set 11 | buchanan
# Processing Record 3 of the Set 11 | alamos
# Processing Record 4 of the Set 11 | belle fourche
# Processing Record 5 of the Set 11 | bamako
# Processing Record 6 of the Set 11 | hov
# Processing Record 7 of the Set 11 | nanzhang
# Processing Record 8 of the Set 11 | los algarrobos
# Processing Record 9 of the Set 11 | miri
# Processing Record 10 of the Set 11 | vigrestad
# Processing Record 11 of the Set 11 | rorvik
# Processing Record 12 of the Set 11 | prince rupert
# Processing Record 13 of the Set 11 | labutta
# Processing Record 14 of the Set 11 | princeton
# Processing Record 15 of the Set 11 | churapcha
# Processing Record 16 of the Set 11 | necochea
# Processing Record 17 of the Set 11 | zhangjiakou
# Processing Record 18 of the Set 11 | tabou
# Processing Record 19 of the Set 11 | port macquarie
# Processing Record 20 of the Set 11 | oranjestad
# Processing Record 21 of the Set 11 | alpinopolis
# Processing Record 22 of the Set 11 | freeport
# Processing Record 23 of the Set 11 | alice springs
# Processing Record 24 of the Set 11 | mutoko
# Processing Record 25 of the Set 11 | haradok
# Processing Record 26 of the Set 11 | brownsville
# Processing Record 27 of the Set 11 | ondarroa
# Processing Record 28 of the Set 11 | bardiyah
# Processing Record 29 of the Set 11 | mayya
# Processing Record 30 of the Set 11 | parana
# Processing Record 31 of the Set 11 | custodia
# Processing Record 32 of the Set 11 | siquijor
# Processing Record 33 of the Set 11 | turbat
# Processing Record 34 of the Set 11 | ewa beach
# Processing Record 35 of the Set 11 | maldonado
# Processing Record 36 of the Set 11 | dryden
# Processing Record 37 of the Set 11 | caraguatatuba
# Processing Record 38 of the Set 11 | tromso
# Processing Record 39 of the Set 11 | gigmoto
# Processing Record 40 of the Set 11 | amarillo
# Processing Record 41 of the Set 11 | ukhta
# Processing Record 42 of the Set 11 | perambalur
# Processing Record 43 of the Set 11 | nur
# Processing Record 44 of the Set 11 | tolmachevo
# Processing Record 45 of the Set 11 | popondetta
# Processing Record 46 of the Set 11 | dwarka
# Processing Record 47 of the Set 11 | hammerfest
# Processing Record 48 of the Set 11 | tiarei
# Processing Record 49 of the Set 11 | mponela
# Processing Record 50 of the Set 11 | lafayette
# Processing Record 1 of the Set 12 | sabibah
# City not found. Skipping...
# Processing Record 2 of the Set 12 | bud
# Processing Record 3 of the Set 12 | tecoanapa
# Processing Record 4 of the Set 12 | namibe
# Processing Record 5 of the Set 12 | kerzhenets
# Processing Record 6 of the Set 12 | bondo
# Processing Record 7 of the Set 12 | boa vista
# Processing Record 8 of the Set 12 | tabas
# Processing Record 9 of the Set 12 | madingou
# Processing Record 10 of the Set 12 | samarai
# Processing Record 11 of the Set 12 | marcona
# Processing Record 12 of the Set 12 | rudbar
# Processing Record 13 of the Set 12 | minab
# Processing Record 14 of the Set 12 | odweyne
# Processing Record 15 of the Set 12 | le mars
# Processing Record 16 of the Set 12 | nyurba
# Processing Record 17 of the Set 12 | bandarban
# Processing Record 18 of the Set 12 | guangyuan
# Processing Record 19 of the Set 12 | murchison
# Processing Record 20 of the Set 12 | sedam
# Processing Record 21 of the Set 12 | bacolod
# Processing Record 22 of the Set 12 | mizan teferi
# Processing Record 23 of the Set 12 | pisco
# Processing Record 24 of the Set 12 | roebourne
# Processing Record 25 of the Set 12 | dobson
# Processing Record 26 of the Set 12 | sur
# Processing Record 27 of the Set 12 | riohacha
# Processing Record 28 of the Set 12 | constitucion
# Processing Record 29 of the Set 12 | erenhot
# Processing Record 30 of the Set 12 | bumba
# Processing Record 31 of the Set 12 | ottawa
# Processing Record 32 of the Set 12 | hellin
# Processing Record 33 of the Set 12 | mirnyy
# Processing Record 34 of the Set 12 | saint-augustin
# Processing Record 35 of the Set 12 | ardistan
# Processing Record 36 of the Set 12 | salta
# Processing Record 37 of the Set 12 | sundargarh
# Processing Record 38 of the Set 12 | bandarbeyla
# Processing Record 39 of the Set 12 | fuerte olimpo
# Processing Record 40 of the Set 12 | pak phanang
# Processing Record 41 of the Set 12 | naftah
# City not found. Skipping...
# Processing Record 42 of the Set 12 | kaeo
# Processing Record 43 of the Set 12 | chicama
# Processing Record 44 of the Set 12 | constitucion
# Processing Record 45 of the Set 12 | metro
# Processing Record 46 of the Set 12 | hovd
# Processing Record 47 of the Set 12 | mareeba
# Processing Record 48 of the Set 12 | fereydunshahr
# Processing Record 49 of the Set 12 | areosa
# Processing Record 50 of the Set 12 | carbonia
# Processing Record 1 of the Set 13 | kidal
# Processing Record 2 of the Set 13 | alofi
# Processing Record 3 of the Set 13 | huntington
# Processing Record 4 of the Set 13 | ginir
# Processing Record 5 of the Set 13 | satitoa
# City not found. Skipping...
# Processing Record 6 of the Set 13 | kiruna
# Processing Record 7 of the Set 13 | ust-kuyga
# Processing Record 8 of the Set 13 | padang
# Processing Record 9 of the Set 13 | grindavik
# Processing Record 10 of the Set 13 | nantucket
# Processing Record 11 of the Set 13 | nynashamn
# Processing Record 12 of the Set 13 | reconquista
# Processing Record 13 of the Set 13 | kangaatsiaq
# Processing Record 14 of the Set 13 | nemuro
# Processing Record 15 of the Set 13 | oytal
# Processing Record 16 of the Set 13 | auki
# Processing Record 17 of the Set 13 | amahai
# Processing Record 18 of the Set 13 | ayan
# Processing Record 19 of the Set 13 | berdigestyakh
# Processing Record 20 of the Set 13 | irbil
# Processing Record 21 of the Set 13 | at-bashi
# Processing Record 22 of the Set 13 | egvekinot
# Processing Record 23 of the Set 13 | puerto leguizamo
# Processing Record 24 of the Set 13 | kambarka
# Processing Record 25 of the Set 13 | kritsa
# Processing Record 26 of the Set 13 | verkhnevilyuysk
# Processing Record 27 of the Set 13 | ancud
# Processing Record 28 of the Set 13 | pleasanton
# Processing Record 29 of the Set 13 | neiafu
# Processing Record 30 of the Set 13 | kavaratti
# Processing Record 31 of the Set 13 | tiznit
# Processing Record 32 of the Set 13 | jishou
# Processing Record 33 of the Set 13 | atasu
# Processing Record 34 of the Set 13 | chingirlau
# Processing Record 35 of the Set 13 | elliot
# Processing Record 36 of the Set 13 | ondorhaan
# Processing Record 37 of the Set 13 | mergui
# Processing Record 38 of the Set 13 | sarandi
# Processing Record 39 of the Set 13 | bolungarvik
# Processing Record 40 of the Set 13 | buraydah
# City not found. Skipping...
# Processing Record 41 of the Set 13 | pangnirtung
# Processing Record 42 of the Set 13 | nurota
# Processing Record 43 of the Set 13 | nizhniy tsasuchey
# Processing Record 44 of the Set 13 | amazar
# Processing Record 45 of the Set 13 | alto araguaia
# Processing Record 46 of the Set 13 | areia branca
# Processing Record 47 of the Set 13 | asyut
# Processing Record 48 of the Set 13 | geraldton
# Processing Record 49 of the Set 13 | yanan
# Processing Record 50 of the Set 13 | ayr
# Processing Record 1 of the Set 14 | cirebon
# Processing Record 2 of the Set 14 | narsaq
# Processing Record 3 of the Set 14 | turukhansk
# Processing Record 4 of the Set 14 | wanning
# Processing Record 5 of the Set 14 | svetlyy
# Processing Record 6 of the Set 14 | stavern
# Processing Record 7 of the Set 14 | tecpan
# Processing Record 8 of the Set 14 | georgetown
# Processing Record 9 of the Set 14 | kepanjen
# Processing Record 10 of the Set 14 | bilma
# Processing Record 11 of the Set 14 | vostok
# Processing Record 12 of the Set 14 | aksehir
# Processing Record 13 of the Set 14 | de aar
# Processing Record 14 of the Set 14 | san vicente
# Processing Record 15 of the Set 14 | port hardy
# Processing Record 16 of the Set 14 | quzhou
# Processing Record 17 of the Set 14 | naze
# Processing Record 18 of the Set 14 | chippewa falls
# Processing Record 19 of the Set 14 | bolshegrivskoye
# Processing Record 20 of the Set 14 | raudeberg
# Processing Record 21 of the Set 14 | port hedland
# Processing Record 22 of the Set 14 | providencia
# Processing Record 23 of the Set 14 | athens
# Processing Record 24 of the Set 14 | la ronge
# Processing Record 25 of the Set 14 | alekseyevsk
# Processing Record 26 of the Set 14 | nouakchott
# Processing Record 27 of the Set 14 | vytegra
# Processing Record 28 of the Set 14 | vila
# Processing Record 29 of the Set 14 | komsomolskiy
# Processing Record 30 of the Set 14 | doha
# Processing Record 31 of the Set 14 | tara
# Processing Record 32 of the Set 14 | smidovich
# Processing Record 33 of the Set 14 | north platte
# Processing Record 34 of the Set 14 | jieshi
# Processing Record 35 of the Set 14 | bowen
# Processing Record 36 of the Set 14 | tanshui
# City not found. Skipping...
# Processing Record 37 of the Set 14 | thohoyandou
# Processing Record 38 of the Set 14 | ndende
# Processing Record 39 of the Set 14 | nortelandia
# Processing Record 40 of the Set 14 | puri
# Processing Record 41 of the Set 14 | sungaipenuh
# Processing Record 42 of the Set 14 | muzhi
# Processing Record 43 of the Set 14 | chagda
# Processing Record 44 of the Set 14 | buala
# Processing Record 45 of the Set 14 | kurchum
# Processing Record 46 of the Set 14 | porbandar
# Processing Record 47 of the Set 14 | dukat
# Processing Record 48 of the Set 14 | pau dos ferros
# Processing Record 49 of the Set 14 | zhuanghe
# Processing Record 50 of the Set 14 | pucheni
# Processing Record 1 of the Set 15 | chifeng
# Processing Record 2 of the Set 15 | azimur
# Processing Record 3 of the Set 15 | kutum
# Processing Record 4 of the Set 15 | yulara
# Processing Record 5 of the Set 15 | klaksvik
# Processing Record 6 of the Set 15 | terrace
# Processing Record 7 of the Set 15 | sangmelima
# Processing Record 8 of the Set 15 | maumere
# Processing Record 9 of the Set 15 | eureka
# Processing Record 10 of the Set 15 | pointe michel
# Processing Record 11 of the Set 15 | calvinia
# Processing Record 12 of the Set 15 | kariba
# Processing Record 13 of the Set 15 | hay river
# Processing Record 14 of the Set 15 | tacuarembo
# Processing Record 15 of the Set 15 | kegums
# Processing Record 16 of the Set 15 | almaznyy
# Processing Record 17 of the Set 15 | jinchang
# Processing Record 18 of the Set 15 | savannah bight
# Processing Record 19 of the Set 15 | les cayes
# Processing Record 20 of the Set 15 | toftir
# Processing Record 21 of the Set 15 | nagato
# Processing Record 22 of the Set 15 | shimoda
# Processing Record 23 of the Set 15 | vulpeni
# Processing Record 24 of the Set 15 | xambioa
# Processing Record 25 of the Set 15 | davila
# Processing Record 26 of the Set 15 | labuan
# Processing Record 27 of the Set 15 | puro
# Processing Record 28 of the Set 15 | filadelfia
# Processing Record 29 of the Set 15 | qandala
# Processing Record 30 of the Set 15 | kota bahru
# Processing Record 31 of the Set 15 | usinsk
# Processing Record 32 of the Set 15 | kochinda
# Processing Record 33 of the Set 15 | suhbaatar
# Processing Record 34 of the Set 15 | sola
# Processing Record 35 of the Set 15 | sistranda
# Processing Record 36 of the Set 15 | sao mateus do sul
# Processing Record 37 of the Set 15 | anchorage
# Processing Record 38 of the Set 15 | ostrovnoy
# Processing Record 39 of the Set 15 | tual
# Processing Record 40 of the Set 15 | mehamn
# Processing Record 41 of the Set 15 | valparaiso
# Processing Record 42 of the Set 15 | diamantino
# Processing Record 43 of the Set 15 | viedma
# Processing Record 44 of the Set 15 | lipari
# ------------------------------
# Data Retrieval Complete

# %%
len(cities)
# Out:
# 744

# %%
city_data_df = pd.DataFrame(city_data)
city_weather_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_weather_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bluff      NZ -46.6000  168.3333     38.80        87         100
# 1  Upernavik      GL  72.7868  -56.1549     40.59        94          97
# 2    Rikitea      PF -23.1203 -134.9692     74.50        77          10
# 3     Palora      EC  -1.7000  -77.9333     68.05        88          82
# 4     Yetkul      RU  54.8221   61.5880     53.58        80           2
#
#    Wind Speed Current Description
# 0        6.69     overcast clouds
# 1        9.10     overcast clouds
# 2       13.44           clear sky
# 3        3.49          light rain
# 4        8.95           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
